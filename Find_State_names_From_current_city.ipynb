# %%
import pandas as pd
import os

# %%
df = pd.read_csv('dataset/Area_Location.csv')

# %%
df.head()
# Out:
#   Maharastra_SUB-DISTRICT KARNATAKA_SUB-DISTRICT ODISHA_SUB-DISTRICT  \
# 0             MAHARASHTRA              KARNATAKA              ODISHA
# 1               Nandurbar                Belgaum             Bargarh
# 2               Akkalkuwa                Chikodi            Paikamal
# 3                  Akrani                  Athni          Jharbandha
# 4                  Talode                 Raybag            Padmapur
#
#   ANDHRA PRADESH_SUB-DISTRICT WEST BENGAL_SUB-DISTRICT  \
# 0              ANDHRA PRADESH              WEST BENGAL
# 1                    Adilabad                Darjiling
# 2                       Tamsi                      NaN
# 3                      Jainad      Darjeeling Pulbazar
# 4                        Bela          Rangli Rangliot
#
#   MADHYA PRADESH_SUB-DISTRICT TAMIL NADU_SUB-DISTRICT  \
# 0              MADHYA PRADESH              TAMIL NADU
# 1                     Sheopur             Thiruvallur
# ...

# %%
df['Maharastra_SUB-DISTRICT'] = df['Maharastra_SUB-DISTRICT'].str.lower()
df['KARNATAKA_SUB-DISTRICT'] = df['KARNATAKA_SUB-DISTRICT'].str.lower()
df['ODISHA_SUB-DISTRICT'] = df['ODISHA_SUB-DISTRICT'].str.lower()
df['ANDHRA PRADESH_SUB-DISTRICT'] = df['ANDHRA PRADESH_SUB-DISTRICT'].str.lower()
df['WEST BENGAL_SUB-DISTRICT'] = df['WEST BENGAL_SUB-DISTRICT'].str.lower()
df['MADHYA PRADESH_SUB-DISTRICT'] = df['MADHYA PRADESH_SUB-DISTRICT'].str.lower()
df['TAMIL NADU_SUB-DISTRICT'] = df['TAMIL NADU_SUB-DISTRICT'].str.lower()
df['UTTAR PRADESH_SUB-DISTRICT'] = df['UTTAR PRADESH_SUB-DISTRICT'].str.lower()
df['RAJASTHAN_SUB-DISTRICT'] = df['RAJASTHAN_SUB-DISTRICT'].str.lower()
df['PUNJAB_SUB-DISTRICT'] = df['PUNJAB_SUB-DISTRICT'].str.lower()
df['KERALA_SUB-DISTRICT'] = df['KERALA_SUB-DISTRICT'].str.lower()
df['BIHAR_SUB-DISTRICT'] = df['BIHAR_SUB-DISTRICT'].str.lower()
df['HARYANA_SUB-DISTRICT'] = df['HARYANA_SUB-DISTRICT'].str.lower()
df['HIMACHAL PRADESH_SUB-DISTRICT'] = df['HIMACHAL PRADESH_SUB-DISTRICT'].str.lower()
df['ARUNACHAL PRADESH_SUB-DISTRICT'] = df['ARUNACHAL PRADESH_SUB-DISTRICT'].str.lower()
df['ASSAM_SUB-DISTRICT'] = df['ASSAM_SUB-DISTRICT'].str.lower()
df['GUJARAT_SUB-DISTRICT'] = df['GUJARAT_SUB-DISTRICT'].str.lower()
df['DELHI_SUB-DISTRICT'] = df['DELHI_SUB-DISTRICT'].str.lower()
df['CHHATTISGARH_SUB-DISTRICT'] = df['CHHATTISGARH_SUB-DISTRICT'].str.lower()
df['GOA_SUB-DISTRICT'] = df['GOA_SUB-DISTRICT'].str.lower()
df['TRIPURA_SUB-DISTRICT'] = df['TRIPURA_SUB-DISTRICT'].str.lower()
df['JHARKHAND_SUB-DISTRICT'] = df['JHARKHAND_SUB-DISTRICT'].str.lower()
df['UTTARAKHAND_SUB-DISTRICT'] = df['UTTARAKHAND_SUB-DISTRICT'].str.lower()

# %%
MAHARASTRA = df['Maharastra_SUB-DISTRICT'].dropna().unique().tolist()
KARNATAKA = df['KARNATAKA_SUB-DISTRICT'].dropna().unique().tolist()
ODISHA = df['ODISHA_SUB-DISTRICT'].dropna().unique().tolist()
ANDHRA_PRADESH = df['ANDHRA PRADESH_SUB-DISTRICT'].dropna().unique().tolist()
WEST_BENGAL = df['WEST BENGAL_SUB-DISTRICT'].dropna().unique().tolist()
MADHYA_PRADESH = df['MADHYA PRADESH_SUB-DISTRICT'].dropna().unique().tolist()
TAMIL_NADU = df['TAMIL NADU_SUB-DISTRICT'].dropna().unique().tolist()
UTTAR_PRADESH = df['UTTAR PRADESH_SUB-DISTRICT'].dropna().unique().tolist()
RAJASTHAN = df['RAJASTHAN_SUB-DISTRICT'].dropna().unique().tolist()
PUNJAB = df['PUNJAB_SUB-DISTRICT'].dropna().unique().tolist()
KERALA = df['KERALA_SUB-DISTRICT'].dropna().unique().tolist()
BIHAR = df['BIHAR_SUB-DISTRICT'].dropna().unique().tolist()
HARYANA = df['HARYANA_SUB-DISTRICT'].dropna().unique().tolist()
HIMACHAL_PRADESH = df['HIMACHAL PRADESH_SUB-DISTRICT'].dropna().unique().tolist()
ARUNACHAL_PRADESH = df['ARUNACHAL PRADESH_SUB-DISTRICT'].dropna().unique().tolist()
ASSAM = df['ASSAM_SUB-DISTRICT'].dropna().unique().tolist()
GUJARAT = df['GUJARAT_SUB-DISTRICT'].dropna().unique().tolist()
DELHI = df['DELHI_SUB-DISTRICT'].dropna().unique().tolist()
CHHATTISGARH = df['CHHATTISGARH_SUB-DISTRICT'].dropna().unique().tolist()
GOA = df['GOA_SUB-DISTRICT'].dropna().unique().tolist()
TRIPURA = df['TRIPURA_SUB-DISTRICT'].dropna().unique().tolist()
JHARKHAND = df['JHARKHAND_SUB-DISTRICT'].dropna().unique().tolist()
UTTARAKHAND = df['UTTARAKHAND_SUB-DISTRICT'].dropna().unique().tolist()

# %%
State_Location = {
    'MAHARASTRA': MAHARASTRA,
    'KARNATAKA': KARNATAKA,
    'ODISHA': ODISHA,
    'ANDHRA_PRADESH': ANDHRA_PRADESH,
    'WEST_BENGAL': WEST_BENGAL,
    'MADHYA_PRADESH':MADHYA_PRADESH,
    'TAMIL_NADU': TAMIL_NADU,
    'UTTAR_PRADESH': UTTAR_PRADESH,
    'RAJASTHAN': RAJASTHAN,
    'PUNJAB': PUNJAB,
    'KERALA': KERALA,
    'BIHAR': BIHAR,
    'HARYANA':HARYANA,
    'HIMACHAL_PRADESH':HIMACHAL_PRADESH,
    'ARUNACHAL_PRADESH':ARUNACHAL_PRADESH,
    'ASSAM':ASSAM,
    'GUJARAT':GUJARAT,
    'DELHI': DELHI,
    'CHHATTISGARH':CHHATTISGARH,
    'GOA': GOA,
    'TRIPURA':TRIPURA,
    'JHARKHAND':JHARKHAND,
    'UTTARAKHAND':UTTARAKHAND
}

# %%
keys = State_Location.keys()
keys
# Out:
# dict_keys(['MAHARASTRA', 'KARNATAKA', 'ODISHA', 'ANDHRA_PRADESH', 'WEST_BENGAL', 'MADHYA_PRADESH', 'TAMIL_NADU', 'UTTAR_PRADESH', 'RAJASTHAN', 'PUNJAB', 'KERALA', 'BIHAR', 'HARYANA', 'HIMACHAL_PRADESH', 'ARUNACHAL_PRADESH', 'ASSAM', 'GUJARAT', 'DELHI', 'CHHATTISGARH', 'GOA', 'TRIPURA', 'JHARKHAND', 'UTTARAKHAND'])

# %%
'nanded' in State_Location['MAHARASTRA']
# Out:
# True

# %%
def get_key(val): 
    for key, values in State_Location.items():
        #print(value)
        for value in values:
            if val == value:
                return key 
    return "key doesn't exist"
# get_key('bhubaneswar')

# %%
test_location_df = pd.read_csv('dataset/Permnent_address_test_location.csv')
print(test_location_df.shape)
test_location_df.columns
# Out:
# (78, 1)
# Index(['Location'], dtype='object')

# %%
test_location_df['Location'] = test_location_df['Location'].str.lower()

test_location_df['Location'] = test_location_df['Location'].str.replace('[#,@,&,(,),.,/,;]', ' ').dropna()

test_location = test_location_df['Location'].str.replace(',', ' ')

# %%
test_location[:5]
# Out:
# 0                                       assam hatisar
# 1    37b 209 sant nagar nagla haweli dayalbagh agra...
# 2    a p-varunji  tal-karad dist-satara maharashtra...
# 3                                                latur
# 4          a p krushi devata nagar  baramati dist-pune
# Name: Location, dtype: object

# %%
key = ['MAHARASTRA', 'KARNATAKA', 'ODISHA', 'ANDHRA PRADESH', 'WEST BENGAL', 'MADHYA PRADESH', 'TAMIL NADU', 'UTTAR PRADESH', 'RAJASTHAN', 'PUNJAB', 'KERALA', 'BIHAR', 'HARYANA', 'HIMACHAL PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'GUJARAT', 'DELHI', 'CHHATTISGARH', 'GOA', 'TRIPURA', 'JHARKHAND']
key_lower = [e.lower() for e in key]

# %%
def Test_Location(review):
    state_loc = []
    review = str(review).strip()
    if review in key_lower:
        state = get_key(review)
        return state
    for token in review.split():
        token = ''.join(e.lower() for e in token if e.isalnum())
        token = token.strip()
        state = get_key(token)
        state_loc.append(state)
    return ' '.join(state_loc)

# %%
count = 0
state_name_list = []
file_path = "State_output.csv"
if not os.path.exists(file_path):
    df = pd.DataFrame(columns=['current_Location', 'State_location'])
    df.to_csv('State_output.csv')
    print("File Created Successfully...!")
    
test_df = pd.read_csv('State_output.csv', index_col=[0])   

for _, item in test_location_df.iterrows():
    state_names = Test_Location(item['Location'])
    if "key doesn't exist" in state_names:
        state_names = state_names.replace("key doesn't exist", '').strip()
        for state_name in state_names.split():
            if state_name not in state_name_list:
                state_name_list.append(state_name)
        if len(state_name_list) > 0:
            state_list_value = state_name_list[-1]
            print(item['Location'],'*********',state_list_value)
            test_df = test_df.append(pd.Series([item['Location'],state_list_value], index=df.columns), ignore_index=True)
        else:
            print("no state found...",item['Location'])
            test_df = test_df.append(pd.Series([item['Location'],'state_not_found'], index=df.columns), ignore_index=True)
            count = count +1
        state_name_list = []
    else:
        print(item['Location'],'*********',state_names)
        state_names = state_names.split()[-1]
        test_df = test_df.append(pd.Series([item['Location'],state_names], index=df.columns), ignore_index=True)
print("---------Count of State Not found Records...",count)
test_df.to_csv('State_output.csv')
# Out:
# File Created Successfully...!
# assam hatisar  ********* ASSAM
# 37b 209 sant nagar nagla haweli dayalbagh agra 282005 ********* UTTAR_PRADESH
# a p-varunji  tal-karad dist-satara maharashtra 415124 ********* MAHARASTRA
# latur ********* MAHARASTRA
# a p krushi devata nagar  baramati dist-pune ********* MAHARASTRA
# munger  bihar ********* BIHAR BIHAR
# dhule  maharashtra ********* MAHARASTRA MAHARASTRA
# lucknow ********* UTTAR_PRADESH
# nawada bihar ********* BIHAR BIHAR
# sai homes apartment  akurdi pune ********* MAHARASTRA
# jaipur ********* WEST_BENGAL
# a301  yashwant nagar  shivane  pune-23 ********* MAHARASTRA
# nellore  andhra pradesh ********* ANDHRA_PRADESH
# belgaum ********* KARNATAKA
# sinnar nashik ********* MAHARASTRA MAHARASTRA
# kasaragod  kerala ********* KERALA KERALA
# varanasi ********* UTTAR_PRADESH
# bangalore ********* KARNATAKA
# 7-6-20 83  7th ward sriram nagar   giddalur ********* ANDHRA_PRADESH
# kerala ********* KERALA
# ...
